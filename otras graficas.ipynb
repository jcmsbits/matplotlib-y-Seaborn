# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.random.randint(0,50, 1000)

# %% [markdown]
# ### Histograma

# %%
plt.hist(data)
plt.show()

# %%
plt.hist(data, bins = 30, histtype='step')
plt.show()

# %% [markdown]
# ### Boxplot

# %%
plt.boxplot(data, vert=False, patch_artist=True)
plt.show()

# %%
data = np.append(data, 200)

# %% [markdown]
# El paramatro showfliers = False me quita los atípicos en la gráficas

# %%
plt.boxplot(data, vert=False, patch_artist=True, notch=True, showfliers=False)
plt.show()

# %% [markdown]
# ### Scatter

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
area = (30 * np.random.rand(N)) ** 2
colors = np.random.rand(N)

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.scatter(x,y, s=area, c = colors, marker = 's', alpha=0.5)
plt.show()
